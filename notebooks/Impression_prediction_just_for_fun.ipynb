# %% [markdown]
# # Importing Modules

# %%
# To Preproccesing our data
from sklearn.preprocessing import LabelEncoder

# To fill missing values
from sklearn.impute import SimpleImputer

# To Split our train data
from sklearn.model_selection import train_test_split

# To Visualize Data
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.api as sm
# To Train our data
from xgboost import XGBClassifier
from sklearn.utils import shuffle
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB, GaussianNB , MultinomialNB
from sklearn.preprocessing import StandardScaler, normalize

# To evaluate end result we have
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import (
                             log_loss,
                             precision_score,
                             recall_score)
from sklearn.model_selection import LeaveOneOut


# Importing Pandas an Numpy Libraries to use on manipulating our Data
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score,RandomizedSearchCV

# %%
import sys
sys.path.append("../scripts")
from ml_pipeline import run_train_pipeline,dvc_get_data
from db_api import Database_api

# %%
db_api = Database_api()

# %% [markdown]
# # Getting data from the preproccessed table

# %%
warehouse = db_api.get_db_data_from_table_name('mlready_warehouse')
# Out:
# 2022-08-10 17:03:11,358:logger:successfully fetched the data

# %%
warehouse
# Out:
#        campaign_id                                           game_key  \
# 0          l5kk3r3  adunit-facebook-conversational-commerce-phase-...
# 1          l5kk3r3  adunit-facebook-conversational-commerce-phase-...
# 2          l5kk3r3  adunit-facebook-conversational-commerce-phase-...
# 3          l5kk3r3  adunit-facebook-conversational-commerce-phase-...
# 4          l5kk3r3  adunit-facebook-conversational-commerce-phase-...
# ...            ...                                                ...
# 422222     rom3zao  3c741855acd9576b4e311d5cd990ae77/ce493e9ed768f...
# 422223     rom3zao  ccce5533b26203d07100376c394951a6/e69efe69bb576...
# 422224     rom3zao  676e0507f9e1ed8fa6880eafcf91547b/fee75db580219...
# 422225     rom3zao  38534b16ec1e64274db67b5de478c86d/1184b78ee9795...
# 422226     rom3zao  fe1cc47f2e46f29607046541f8418275/75849459a46b6...
#
#               type  width  height creative_id  \
# 0       impression  300.0   300.0    x83byc8a
# 1       impression  300.0   300.0    x83byc8a
# 2       impression  300.0   300.0    tf2htrrm
# 3       impression  300.0   300.0    x83byc8a
# 4       impression  300.0   300.0    x83byc8a
# ...            ...    ...     ...         ...
# 422222  impression  300.0   250.0    b385e5s9
# 422223  impression  300.0   250.0    s54usm6e
# 422224  impression  300.0   250.0    aydslxzq
# 422225  impression  300.0   250.0    18mljlwy
# 422226  impression  300.0   250.0    3csifi69
#
#                                   auction_id                       browser_ts  \
# 0       fd74243f-6606-4830-a0ef-dd12f66ec6f5 2021-01-01 19:55:20.291000+00:00
# 1       fd74243f-6606-4830-a0ef-dd12f66ec6f5 2021-01-01 19:55:20.298000+00:00
# 2       b3af878b-fd1a-4c6f-91a2-4e3670d2fda5 2021-01-05 00:21:39.693000+00:00
# 3       b7c22590-e784-43cf-874d-a661ad99601f 2021-01-06 09:30:44.188000+00:00
# 4       b7c22590-e784-43cf-874d-a661ad99601f 2021-01-06 09:30:45.047000+00:00
# ...                                      ...                              ...
# 422222  ca74860c-fa94-425b-b51a-9ef28ae7279e 2021-02-08 18:17:49.721000+00:00
# 422223  19618aa3-af95-44f2-beea-06958d0af730 2021-02-08 18:17:50.782000+00:00
# 422224  347bde1b-1b7b-4adf-8603-0dd1954466ee 2021-02-08 18:17:51.290000+00:00
# 422225  2440c057-02e7-4440-bcfb-15b113d1df18 2021-02-08 18:17:52.325000+00:00
# 422226  47f5bfde-1901-46c3-8ec8-52797cc83291 2021-02-08 18:17:52.432000+00:00
#
#           geo_country                site_name  ...  buy_rate_cpe  \
# 0            Thailand       www.wuxiaworld.com  ...          0.28
# 1            Thailand       www.wuxiaworld.com  ...          0.28
# 2            Thailand       www.prachachat.net  ...          0.28
# 3            Thailand       www.prachachat.net  ...          0.28
# 4            Thailand       www.prachachat.net  ...          0.28
# ...               ...                      ...  ...           ...
# 422222  United States                afk.guide  ...          0.40
# 422223  United States   www.acommunaltable.com  ...          0.40
# 422224  United States             g1.globo.com  ...          0.40
# 422225  United States          www.foxnews.com  ...          0.40
# 422226  United States  grilledcheesesocial.com  ...          0.40
#
#        volume_agreed gross_costbudget  agency_fee percentage   net_cost  \
# 0           242185.0          67811.8  Percentage       15.0   57640.03
# 1           242185.0          67811.8  Percentage       15.0   57640.03
# 2           242185.0          67811.8  Percentage       15.0   57640.03
# 3           242185.0          67811.8  Percentage       15.0   57640.03
# 4           242185.0          67811.8  Percentage       15.0   57640.03
# ...              ...              ...         ...        ...        ...
# 422222      531179.0         212471.6  Percentage        0.0  212471.60
# 422223      531179.0         212471.6  Percentage        0.0  212471.60
# 422224      531179.0         212471.6  Percentage        0.0  212471.60
# 422225      531179.0         212471.6  Percentage        0.0  212471.60
# 422226      531179.0         212471.6  Percentage        0.0  212471.60
#
#        row_num       ER       CTR         TR
# 0            1   0.0000  0.000000   0.000000
# 1            1   0.0000  0.000000   0.000000
# 2            1   0.0000  0.000000   0.000000
# 3            1   0.0000  0.000000   0.000000
# 4            1   0.0000  0.000000   0.000000
# ...        ...      ...       ...        ...
# 422222       1  13.8097  9.564359  11.687029
# 422223       1  13.8097  9.564359  11.687029
# 422224       1  13.8097  9.564359  11.687029
# 422225       1  13.8097  9.564359  11.687029
# 422226       1  13.8097  9.564359  11.687029
#
# [422227 rows x 43 columns]

# %% [markdown]
# # order the data with campaign id
#     - I am doing this because while dividing the data between traing and testsets i want to get diffrent campaigns on both ends so that our prediction would be close to non biased one

# %%
warehouse = warehouse.sort_values(by='campaign_id', ascending=False)
# warehouse

# %%
choosen_df = warehouse[['type' ,'gross_costbudget' , 'currency' , 'blackwhiteaudience_list_included','net_cost', 'percentage' , 'platform_os' , "buy_rate_cpe" , "geo_country" , "cost_centre" , "site_name"]]

# %%
choosen_df.dropna(inplace=True)
choosen_df
# Out:
# /home/hp/miniconda3/envs/airflow_env/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#               type  gross_costbudget currency  \
# 211113  impression               0.0      USD
# 205704  impression               0.0      USD
# 205709  impression               0.0      USD
# 205708  impression               0.0      USD
# 205707  impression               0.0      USD
# ...            ...               ...      ...
# 97373   impression               0.0      USD
# 97374   impression               0.0      USD
# 97375   impression               0.0      USD
# 97376   impression               0.0      USD
# 101646  impression               0.0      USD
#
#                         blackwhiteaudience_list_included  net_cost  \
# 211113  Black/white/audience list will be provided later       0.0
# 205704  Black/white/audience list will be provided later       0.0
# 205709  Black/white/audience list will be provided later       0.0
# 205708  Black/white/audience list will be provided later       0.0
# 205707  Black/white/audience list will be provided later       0.0
# ...                                                  ...       ...
# 97373                 Black/white/audience list included       0.0
# 97374                 Black/white/audience list included       0.0
# 97375                 Black/white/audience list included       0.0
# 97376                 Black/white/audience list included       0.0
# 101646                Black/white/audience list included       0.0
#
#         percentage  platform_os  buy_rate_cpe    geo_country cost_centre  \
# 211113         0.0          5.0          13.0  United States         USA
# 205704         0.0          5.0          13.0  United States         USA
# 205709         0.0          6.0          13.0  United States         USA
# 205708         0.0          6.0          13.0  United States         USA
# 205707         0.0          6.0          13.0  United States         USA
# ...            ...          ...           ...            ...         ...
# 97373         15.0          6.0           0.3  United States         USA
# 97374         15.0          6.0           0.3  United States         USA
# 97375         15.0          6.0           0.3  United States         USA
# 97376         15.0          6.0           0.3  United States         USA
# 101646        15.0          6.0           0.3  United States         USA
#
#                          site_name
# 211113  www.wholesomerecipebox.com
# 205704      parenting.firstcry.com
# 205709                   word.tips
# 205708                chessmoba.us
# 205707       newsinfo.inquirer.net
# ...                            ...
# 97373          www.dailymotion.com
# 97374          www.ebaumsworld.com
# 97375          www.dailymotion.com
# 97376    www.smartcarofamerica.com
# 101646      www.washingtonpost.com
#
# [422223 rows x 11 columns]

# %%
y = choosen_df['type'].apply(lambda x: 0 if x=='impression' else 1 if x=="first_dropped" else 2 if x=="click-through-event" else 0)
x = choosen_df.drop(columns=["type"])
x
# Out:
#         gross_costbudget currency  \
# 211113               0.0      USD
# 205704               0.0      USD
# 205709               0.0      USD
# 205708               0.0      USD
# 205707               0.0      USD
# ...                  ...      ...
# 97373                0.0      USD
# 97374                0.0      USD
# 97375                0.0      USD
# 97376                0.0      USD
# 101646               0.0      USD
#
#                         blackwhiteaudience_list_included  net_cost  \
# 211113  Black/white/audience list will be provided later       0.0
# 205704  Black/white/audience list will be provided later       0.0
# 205709  Black/white/audience list will be provided later       0.0
# 205708  Black/white/audience list will be provided later       0.0
# 205707  Black/white/audience list will be provided later       0.0
# ...                                                  ...       ...
# 97373                 Black/white/audience list included       0.0
# 97374                 Black/white/audience list included       0.0
# 97375                 Black/white/audience list included       0.0
# 97376                 Black/white/audience list included       0.0
# 101646                Black/white/audience list included       0.0
#
#         percentage  platform_os  buy_rate_cpe    geo_country cost_centre  \
# 211113         0.0          5.0          13.0  United States         USA
# 205704         0.0          5.0          13.0  United States         USA
# 205709         0.0          6.0          13.0  United States         USA
# 205708         0.0          6.0          13.0  United States         USA
# 205707         0.0          6.0          13.0  United States         USA
# ...            ...          ...           ...            ...         ...
# 97373         15.0          6.0           0.3  United States         USA
# 97374         15.0          6.0           0.3  United States         USA
# 97375         15.0          6.0           0.3  United States         USA
# 97376         15.0          6.0           0.3  United States         USA
# 101646        15.0          6.0           0.3  United States         USA
#
#                          site_name
# 211113  www.wholesomerecipebox.com
# 205704      parenting.firstcry.com
# 205709                   word.tips
# 205708                chessmoba.us
# 205707       newsinfo.inquirer.net
# ...                            ...
# 97373          www.dailymotion.com
# 97374          www.ebaumsworld.com
# 97375          www.dailymotion.com
# 97376    www.smartcarofamerica.com
# 101646      www.washingtonpost.com
#
# [422223 rows x 10 columns]

# %%
y
# Out:
# 211113    0
# 205704    0
# 205709    0
# 205708    0
# 205707    0
#          ..
# 97373     0
# 97374     0
# 97375     0
# 97376     0
# 101646    0
# Name: type, Length: 422223, dtype: int64

# %% [markdown]
# # Modeling our data using Random Forest Algorithm

# %%
model = RandomForestRegressor(n_estimators = 10, random_state = 42)
str(model)
# Out:
# 'RandomForestRegressor(n_estimators=10, random_state=42)'

# %%
run_train_pipeline(model, x, y, 
                experiment_name='Random Forest impression prediction with cleaned data',
                run_name='sixth_run')
# Out:
# inside train pipeline
# inside label encoder
# 2022-08-10 17:03:24,894:logger:successfully got catagorical columns
# 2022-08-10 17:03:25,821:logger:successfully got catagorical columns
# 2022-08-10 17:03:25,828:logger:successfully got numerical columns
# 2022-08-10 17:03:27,848:logger:RMSE Score: 0.5158724613158701
# 2022-08-10 17:03:27,848:logger:R2_Squared: -0.03482593177296289
# 2022-08-10 17:03:27,849:logger:MAE Score: 0.3088464166951656
# 2022-08-10 17:03:27,855:logger:Accuracy: 19.98 %.
# 2022-08-10 17:03:27,912:logger:feature importance plotted
# 2022/08/10 17:03:27 INFO mlflow.tracking.fluent: Experiment with name 'Random Forest impression prediction with cleaned data' does not exist. Creating a new experiment.
# 2022-08-10 17:04:28,542:logger:API request to http://localhost:5000/api/2.0/mlflow/runs/create failed with exception HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /api/2.0/mlflow/runs/create (Caused by ResponseError('too many 500 error responses'))
# Run - sixth_run is logged to Experiment - Random Forest impression prediction with cleaned data
# {'RMSE Score': 0.52, 'R2_Squared': -0.03, 'MAE Score': 0.31}
